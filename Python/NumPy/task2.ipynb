# %%
import numpy as np

# %%
A = np.array([10, 20, 30, 40])

# %%
B = np.array([1, 2, 3, 4])

# %%
print(f"Addition (A+B): {A + B}")
# Out:
# Addition (A+B): [11 22 33 44]

# %%
print(f"Substraction (A-B): {A - B}")
# Out:
# Substraction (A-B): [ 9 18 27 36]

# %%
print(f"Multiplication (A*B): {A * B}")
# Out:
# Multiplication (A*B): [ 10  40  90 160]

# %%
print(f"Division (A/B): {A / B}")
# Out:
# Division (A/B): [10. 10. 10. 10.]

# %%
print(f"Power (A**2): {A ** 2}")
# Out:
# Power (A**2): [ 100  400  900 1600]

# %%
print(f"np.add Funtions : {np.add(A, B)}")
# Out:
# np.add Funtions : [11 22 33 44]

# %%
print(f"np.subtract functions : {np.subtract(A, B)}")
# Out:
# np.subtract functions : [ 9 18 27 36]
