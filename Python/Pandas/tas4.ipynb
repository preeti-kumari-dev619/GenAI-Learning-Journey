# %%
import pandas as pd

# %%
students = {
    'Name': ['Amit', 'Rahul', 'Neha', 'Sneha', 'Pooja'],
    'Marks': [78, 85, 90, 66, 72],
    'Subject': ['Math', 'Math', 'Science', 'Science', 'Math']
}

# %%
df = pd.DataFrame(students)

# %%
print("First three rows")
print(df.head(3))
# Out:
# First three rows
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1  Rahul     85     Math
# 2   Neha     90  Science

# %%
print("Last two rows")
print(df.tail(2))
# Out:
# Last two rows
#     Name  Marks  Subject
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
print(f"DataFrame Shape: {df.shape}")
# Out:
# DataFrame Shape: (5, 3)

# %%
print(f"Columns Name: {df.columns.tolist()}")
# Out:
# Columns Name: ['Name', 'Marks', 'Subject']
