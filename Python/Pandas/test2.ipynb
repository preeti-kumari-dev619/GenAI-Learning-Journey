# %%
import pandas as pd

# %%
marks = pd.Series([78, 85, 90, 66, 72])

# %%
print("Add 5 grace Marks")
print(marks + 5)
# Out:
# Add 5 grace Marks
# 0    83
# 1    90
# 2    95
# 3    71
# 4    77
# dtype: int64

# %%
print("Subtract 2 from all values")
print(marks - 2)
# Out:
# Subtract 2 from all values
# 0    76
# 1    83
# 2    88
# 3    64
# 4    70
# dtype: int64

# %%
print("Multiply all element with 1.05")
print(marks * 1.05)
# Out:
# Multiply all element with 1.05
# 0    81.90
# 1    89.25
# 2    94.50
# 3    69.30
# 4    75.60
# dtype: float64

# %%
print("Divide all marks by 2")
print(marks / 2)
# Out:
# Divide all marks by 2
# 0    39.0
# 1    42.5
# 2    45.0
# 3    33.0
# 4    36.0
# dtype: float64
