# %%
import pandas as pd

# %%
marks = pd.Series([78, 85, 90, 66, 72])

# %%
print("Series Values")
print(marks.values)
# Out:
# Series Values
# [78 85 90 66 72]

# %%
print("Index")
print(marks.index)
# Out:
# Index
# RangeIndex(start=0, stop=5, step=1)

# %%
print("Data Type")
print(marks.dtype)
# Out:
# Data Type
# int64

# %%
print("First Element")
print(marks.iloc[0])
# Out:
# First Element
# 78

# %%
print("Last second element")
print(marks.iloc[-2])
# Out:
# Last second element
# 66
